# %% [markdown]
# 2번 활성함수 게단
#
# 1. 다음 중에서 퍼셉트론이 분리하지 못하는 입력은 무엇인가?
# ![nn](3번째숙제_그림.png)

# %% [markdown]
# 답 : 퍼셉트론은 선형분리 가능한 문제만 학습할 수 있다. 전부 선형분리 가능하므로 답은 없다.

# %% [markdown]
# 2. 아래의 퍼셉트론에서 입력이 (0,0)일 때 출력은 무엇인가? 손으로 직접 계산해보자. 바이어스를 -0.5로 변경하면 어떻게 되는가?
# ![nn](3번째숙제_그림_2.png)

# %%
import numpy as np
epsilon = 0.0000001

def perceptron(x1, x2, w1, w2, b):
    X = np.array([x1, x2])
    W = np.array([w1, w2])
    B = b
    sum = np.dot(W, X)+B
    if sum > epsilon :
        return 1
    else :
        return 0
    
print(perceptron(0,0, 1.0, 1.0, -1.5)) #기존
print(perceptron(0,0, 1.0, 1.0, -0.5)) #변경후
# Out:
# 0
# 0

# %% [markdown]
# 아래 샘플을 이용하여서 퍼셉트론 학습 알고리즘이 어떻게 진행되는지를 보여라. 학습률은 1.0으로 하고 가중치와 바이어스의 초기값은 w_1=0, w_2=0, b= -1.0 이다.
#
# 각 단계에서 가중치와 바이어스 값을 표시하여야 한다.
# |###|X_1|X_2|출력|
# |------|---|---|---|
# |A|0|1|0|
# |B|1|0|1
# |C|1|2|1|
# |D|2|1|1|

# %%
import numpy as np

epsilon = 0.0000001		# 부동소수점 오차 방지

def step_func(t):		# 퍼셉트론의 활성화 함수
    if t > epsilon: return 1
    else: return 0
# XOR 연산 학습 데이터 세트
X = np.array([			# 훈련 데이터 세트
    [0, 1, 1],			# 맨 끝의 1은 바이어스를 위한 입력 신호 1이다. 
    [1, 0, 1],			# 맨 끝의 1은 바이어스를 위한 입력 신호 1이다. 
    [1, 2, 1],			# 맨 끝의 1은 바이어스를 위한 입력 신호 1이다. 
    [2, 1, 1]			# 맨 끝의 1은 바이어스를 위한 입력 신호 1이다. 
])

y = np.array([0.0, 1.0, 1.0, 1.0])
W = np.array([0.0,0.0,-1.0])	# 가중치를 저장하는 넘파이 행렬

def perceptron_fit(X, Y, epochs=10):	# 퍼셉트론 학습 알고리즘 구현
    global W
    eta = 1.0				# 학습률

    for t in range(epochs):
        print("epoch=", t, "======================")
        for i in range(len(X)):
            predict = step_func(np.dot(X[i], W))
            error = Y[i] - predict		# 오차 계산
            W += eta * error * X[i]		# 가중치 업데이트
            print("현재 처리 입력=",X[i],"정답=",Y[i],"출력=",predict,"변경된 가중치=", W)
        print("================================")

def perceptron_predict(X, Y):		# 예측	
    global W
    for x in X:
         print(x[0], x[1], "->", step_func(np.dot(x, W)))

perceptron_fit(X, y, 6)
perceptron_predict(X, y)
# Out:
# epoch= 0 ======================
# 현재 처리 입력= [0 1 1] 정답= 0.0 출력= 0 변경된 가중치= [ 0.  0. -1.]
# 현재 처리 입력= [1 0 1] 정답= 1.0 출력= 0 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [1 2 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [2 1 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# ...
# epoch= 1 ======================
# 현재 처리 입력= [0 1 1] 정답= 0.0 출력= 0 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [1 0 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [1 2 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [2 1 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# ...
# epoch= 2 ======================
# 현재 처리 입력= [0 1 1] 정답= 0.0 출력= 0 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [1 0 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [1 2 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [2 1 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# ...
# epoch= 3 ======================
# 현재 처리 입력= [0 1 1] 정답= 0.0 출력= 0 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [1 0 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# 현재 처리 입력= [1 2 1] 정답= 1.0 출력= 1 변경된 가중치= [1. 0. 0.]
# ...
