# %%
import matplotlib.pylab as plt
from sklearn import linear_model
import numpy as np
reg = linear_model.LinearRegression()

X = [[1],[2],[3],[4],[5]]
y = [12,19,28,37,46]

reg.fit(X, y)			# 학습

# 학습 데이터와 y 값을 산포도로 그린다. 
plt.scatter(X, y, color='black')

# 학습 데이터를 입력으로 하여 예측값을 계산한다.
y_pred = reg.predict(X)

# 학습 데이터와 예측값으로 선그래프로 그린다. 
# 계산된 기울기와 y 절편을 가지는 직선이 그려진다. 
plt.plot(X, y_pred, color='blue', linewidth=3)		
plt.show()

m = reg.coef_
b = reg.intercept_
print('예측한 직선방정식 : {0}x+{1}'.format(m, b))
print('예측한 2020년도의 매출 :', float(reg.predict([[6]])))

y_pred
# Out:
# 예측한 직선방정식 : [8.6]x+2.5999999999999943
# 예측한 2020년도의 매출 : 54.2
# array([11.2, 19.8, 28.4, 37. , 45.6])

# %%
import matplotlib.pylab as plt
from sklearn import linear_model
import numpy as np
reg = linear_model.LinearRegression()

X=[[0],[10],[20],[30],[40],[50],[60],[80],[86]]
y = [59,62,70,69,71,74,75,76,78]

reg.fit(X, y)			# 학습

# 학습 데이터와 y 값을 산포도로 그린다. 
plt.scatter(X, y, color='black')

# 학습 데이터를 입력으로 하여 예측값을 계산한다.
y_pred = reg.predict(X)

# 학습 데이터와 예측값으로 선그래프로 그린다. 
# 계산된 기울기와 y 절편을 가지는 직선이 그려진다. 
plt.plot(X, y_pred, color='blue', linewidth=3)		
plt.show()

m = reg.coef_
b = reg.intercept_
print('예측한 직선방정식 : {0}x+{1}'.format(m, b))
print('예측한 1962(x = 32)의 기대수명 :', float(reg.predict([[32]])))
# Out:
# 예측한 직선방정식 : [0.19907865]x+62.127380657927276
# 예측한 1962(x = 32)의 기대수명 : 68.49789760079149

# %%
import matplotlib.pylab as plt
from sklearn import linear_model

reg = linear_model.LinearRegression()

X = [[30], [35], [20], [15], [3]]
y = [90, 95, 70, 40, 10]

reg.fit(X, y)			# 학습

# 학습 데이터와 y 값을 산포도로 그린다. 
plt.scatter(X, y, color='black')

# 학습 데이터를 입력으로 하여 예측값을 계산한다.
y_pred = reg.predict(X)

# 학습 데이터와 예측값으로 선그래프로 그린다. 
# 계산된 기울기와 y 절편을 가지는 직선이 그려진다. 
plt.plot(X, y_pred, color='blue', linewidth=3)		
plt.show()
m = reg.coef_
b = reg.intercept_
print('예측한 직선방정식 : {0}x+{1}'.format(m, b))
# Out:
# 예측한 직선방정식 : [2.78091651]x+3.71311989956056
